# %%
from qm.QuantumMachinesManager import QuantumMachinesManager
import time
import matplotlib.pyplot as plt
from Configuration_BMDevice_FreqMixer import *
import numpy as np
import scipy.optimize as opti
from auto_mixer_tools import auto_mixer_cal

# %%
auto_mixer_cal("Q1", "const", Q1_lo, Q1_IF, config)
# Out:
# 2022-01-24 15:55:17,836 - qm - INFO - Performing health check
# 2022-01-24 15:55:17,843 - qm - INFO - Health check passed
# 2022-01-24 15:55:18,200 - qm - INFO - Flags:
# 2022-01-24 15:55:18,201 - qm - INFO - Sending program to QOP
# 2022-01-24 15:55:18,210 - qm - INFO - Executing program
# LO Leakage Results: Found a minimum of -104 dBm at I0 = -0.01125, Q0 = 0.00175 in 10 seconds --- 42 dBc
# Image Rejection Results: Found a minimum of -103 dBm at g = -0.01724, phi = -0.13986 in 12 seconds --- 41 dBc

# %%
auto_mixer_cal("RR_1", "const", RO_lo, RR_1_IF, config)
# Out:
# 2022-01-24 15:50:35,225 - qm - INFO - Performing health check
# 2022-01-24 15:50:35,231 - qm - INFO - Health check passed
# 2022-01-24 15:50:35,395 - qm - INFO - Flags:
# 2022-01-24 15:50:35,396 - qm - INFO - Sending program to QOP
# 2022-01-24 15:50:35,405 - qm - INFO - Executing program
# LO Leakage Results: Found a minimum of -105 dBm at I0 = 0.01786, Q0 = -0.00423 in 10 seconds --- 23 dBc
# Image Rejection Results: Found a minimum of -106 dBm at g = 0.02325, phi = -0.05270 in 10 seconds --- 24 dBc
